# %%
# %%capture
# !git clone https://github.com/ultralytics/yolov5.git
# %cd /content/yolov5
# !pip install -r requirements.txt
# !pip install wandb

# %%
# !python train.py \
--data custom_test.yaml \
--epochs 55 \
--project custom_yolov5 \
--bbox_interval 1 \
--weights yolov5s.pt
# Out:
# wandb: Currently logged in as: rschwieter (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=custom_test.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=55, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=custom_yolov5, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.9.0+cu111 CPU
#
# ...
